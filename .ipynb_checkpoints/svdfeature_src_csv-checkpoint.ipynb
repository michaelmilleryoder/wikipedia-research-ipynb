# %%
import csv
import pandas as pd

# %%
src_bias = pd.read_csv('/home/michael/school/research/wp/wikipedia/data/biased_sources.csv')
src_bias
# Out:
#                                              name  perspective  \
# 0                                        Al-Ahram  Palestinian
# 1                                          Al-Haq  Palestinian
# 2                                    Aloni Shlomo      Israeli
# 3                        American Jewish Congress      Israeli
# 4                           Amnesty International  Palestinian
# 5                          Anti-Defamation League      Israeli
# 6                                    Anti-War.com  Palestinian
# 7                                    Avraham Sela      Israeli
# 8                                        B'tselem  Palestinian
# 9                                     Edward Said  Palestinian
# 10               Foundation for Middle East Peace  Palestinian
# 11                                         gov.il      Israeli
# 12                                         gov.ps  Palestinian
# 13                             Human Rights Watch  Palestinian
# 14  Intelligence and Terrorism Information Center      Israeli
# 15                                 Jerusalem Post      Israeli
# 16                                 Jewish Journal      Israeli
# 17                         Jewish Virtual Library      Israeli
# 18                                          Ma'an  Palestinian
# 19                                 Menachem Klein      Israeli
# 20                                 Mossawa Center  Palestinian
# 21                             Norman Finkelstein  Palestinian
# 22                            Palestine Chronicle  Palestinian
# 23                              Palestine Monitor  Palestinian
# 24      Palestinian Human Rights Monitoring Group  Palestinian
# 25                                       Qumsiyeh  Palestinian
# 26                                       Ynetnews      Israeli
# 27                             Zionism-Israel.com      Israeli
#
#                                         marker  \
# 0                                     al-ahram
# 1                                        alhaq
# 2                                       Shlomo
# 3                                          NaN
# 4                        Amnesty International
# 5                                          adl
# 6                                 anti-war.com
# 7                                         Sela
# 8                                      btselem
# 9                                         Said
# 10                                        fmep
# 11                                      gov.il
# 12                                      gov.ps
# 13                                     hrw.org
# 14  terrorism-info.org.il, intelligence.org.il
# 15                                       jpost
# 16                               jewishjournal
# 17                        jewishvirtuallibrary
# 18                                        Maan
# 19                                       Klein
# 20                                     mossawa
# 21                                 Finkelstein
# 22                          palestinechronicle
# 23                            palestinemonitor
# 24                                       phrmg
# 25                                    qumsiyeh
# 26                                    ynetnews
# 27                          zionism-israel.com
#
#                                                 notes
# 0                                                 NaN
# 1                                                 NaN
# 2   All about Israeli warfare, which is more of a ...
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                 Israeli government
# 12                              Palestinian Authority
# 13                                                NaN
# 14                                                NaN
# 15                      Arab-Israeli Conflict section
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN

# %%
src_bias.iloc[1]['name']
# Out:
# 'Al-Haq'

# %%
outrows = []
inpath = '/home/michael/software/svdfeature-1.2.2/demo/basicMF/itemvecs.txt'
with open(inpath) as f:
    for line in f.read().splitlines():
        parts = line.split('\t')
        iid = int(parts[0])
        ivec = [float(val) for val in parts[1].split()]
        row = [src_bias.iloc[iid]['name'], src_bias.iloc[iid]['perspective']] + ivec
len(outrows)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-55b85afa7509> in <module>()
#       6         iid = parts[0]
#       7         ivec = [float(val) for val in parts[1].split()]
# ----> 8         row = [src_bias.iloc[iid]['name'], src_bias.iloc[iid]['perspective']] + ivec
#       9 len(outrows)
#
# /usr/lib/python3/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1192             return self._getitem_tuple(key)
#    1193         else:
# -> 1194             return self._getitem_axis(key, axis=0)
#    1195
#    1196     def _getitem_axis(self, key, axis=0):
#
# /usr/lib/python3/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1453
#    1454             else:
# -> 1455                 key = self._convert_scalar_indexer(key, axis)
#    1456
#    1457                 if not com.is_integer(key):
#
# /usr/lib/python3/dist-packages/pandas/core/indexing.py in _convert_scalar_indexer(self, key, axis)
#     167         ax = self.obj._get_axis(min(axis, self.ndim - 1))
#     168         # a scalar
# --> 169         return ax._convert_scalar_indexer(key, typ=self.name)
#     170
#     171     def _convert_slice_indexer(self, key, axis):
#
# /usr/lib/python3/dist-packages/pandas/core/index.py in _convert_scalar_indexer(self, key, typ)
#     624                     type(self).__name__),FutureWarning)
#     625                 return key
# --> 626             return self._convert_indexer_error(key, 'label')
#     627
#     628         if is_float(key):
#
# /usr/lib/python3/dist-packages/pandas/core/index.py in _convert_indexer_error(self, key, msg)
#     764             msg = 'label'
#     765         raise TypeError("the {0} [{1}] is not a proper indexer for this index "
# --> 766                         "type ({2})".format(msg, key, self.__class__.__name__))
#     767
#     768     def get_duplicates(self):
#
# TypeError: the label [1] is not a proper indexer for this index type (Int64Index)
